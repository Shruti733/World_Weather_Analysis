# %%
# Import the dependencies
import pandas as pd
import numpy as np
import matplotlib as plt
from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime
import time

# %%
# Create a new set of 2,000 random latitudes and longitudes
latitudes = np.random.uniform(90,-90,2000)
longitudes = np.random.uniform(180,-180,2000)
lat_lng = zip(latitudes,longitudes)
coordinates = list(lat_lng)
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    if city not in cities:
        cities.append(city)

print(cities)
# Out:
# ['bredasdorp', 'vao', 'port alfred', 'syava', 'ushuaia', 'attawapiskat', 'naze', 'faanui', 'mbanza-ngungu', 'fatehgarh churian', 'kapaa', 'vaini', 'coetupo', 'siocon', 'pacific grove', 'rikitea', 'half moon bay', 'cape town', 'saint andrews', 'ribeira grande', 'batangafo', 'beringovskiy', 'tasiilaq', 'mataura', 'busselton', 'matara', 'vanimo', 'yellowknife', 'nizhneyansk', 'east london', 'wladyslawowo', 'saldanha', 'hilo', 'mount pleasant', 'nikolskoye', 'rundu', 'raudeberg', 'barranco', 'somerset east', 'albany', 'ancud', 'meyungs', 'dikson', 'port keats', 'puerto ayora', 'kihei', 'kenora', 'maldonado', 'hithadhoo', 'saint-philippe', 'port lincoln', 'asau', 'hobart', 'mount isa', 'seoul', 'chuy', 'arraial do cabo', 'albertville', 'gat', 'coihaique', 'barrow', 'kharan', 'tumannyy', 'timmins', 'marcona', 'cantaura', 'dingle', 'villazon', 'sentyabrskiy', 'ponta do sol', 'atuona', 'georgetown', 'sarangani', 'upernavik', 'san alberto', 'cherskiy', 'liberty', 'kahului', 'vallenar', 'lyndon', 'qandala', 'geraldton', 'dzaoudzi', 'norman wells', 'sarila', 'concarneau', 'amderma', 'vestmanna', 'kavaratti', 'mar del plata', 'aklavik', 'kodiak', 'castro', 'cidreira', 'komsomolskiy', 'qaanaaq', 'saskylakh', 'tiksi', 'mahebourg', 'saint george', 'haverfordwest', 'airai', 'punta arenas', 'ulladulla', 'vila franca do campo', 'butaritari', 'belushya guba', 'pamekasan', 'krutinka', 'carbonia', 'illoqqortoormiut', 'taolanaro', 'torbay', 'zhezkazgan', 'lompoc', 'karratha', 'cap malheureux', 'clyde river', 'kota bahru', 'lehola', 'quang ngai', 'edd', 'barra dos coqueiros', 'port hardy', 'hermanus', 'nanortalik', 'guerrero negro', 'puerto gaitan', 'san andres', 'paracuru', 'jalu', 'ossora', 'tangwani', 'ust-maya', 'new norfolk', 'tuktoyaktuk', 'mochudi', 'badarganj', 'madang', 'san cristobal', 'ilulissat', 'bambous virieux', 'gorontalo', 'dali', 'liverpool', 'north bend', 'bur gabo', 'atbasar', 'tamandare', 'severo-kurilsk', 'oksfjord', 'kryvyy rih', 'haines junction', 'svetlogorsk', 'port elizabeth', 'la asuncion', 'aswan', 'tetiyiv', 'coquimbo', 'bar harbor', 'narsaq', 'longyearbyen', 'murgab', 'kaitangata', 'ndioum', 'grand river south east', 'benghazi', 'toulepleu', 'nakusp', 'thinadhoo', 'boa vista', 'mandalgovi', 'buin', 'bethel', 'cardonal', 'samusu', 'san policarpo', 'victoria', 'timoteo', 'arman', 'sivaki', 'belyy yar', 'yairipok', 'tecoanapa', 'olavarria', 'bluff', 'katsiveli', 'guaruja', 'pulandian', 'bonaventure', 'mamu kanjan', 'tsihombe', 'chokurdakh', 'morant bay', 'tilichiki', 'nabire', 'waingapu', 'mys shmidta', 'barentsburg', 'wanaka', 'bonavista', 'farafangana', 'kruisfontein', 'catamarca', 'khatanga', 'jamestown', 'adwa', 'lapy', 'sovetskaya gavan', 'aflu', 'banda aceh', 'bedford', 'sataua', 'kuvshinovo', 'praia da vitoria', 'avarua', 'amalapuram', 'longhua', 'bengkulu', 'vardo', 'guaratuba', 'broken hill', 'teknaf', 'mana', 'iacu', 'culipapa', 'evensk', 'yulara', 'rodrigues alves', 'codrington', 'tabiauea', 'voi', 'hendijan', 'sao joao da barra', 'carnarvon', 'motygino', 'andenes', 'iqaluit', 'conde', 'asbury park', 'kurchum', 'charlestown', 'dicabisagan', 'constitucion', 'beyneu', 'provideniya', 'hovd', 'sorong', 'amapa', 'balkhash', 'harper', 'nanakuli', 'namatanai', 'cabo san lucas', 'pevek', 'formosa', 'heihe', 'baie du tombeau', 'meulaboh', 'roma', 'okhotsk', 'kamenskoye', 'bassano', 'padang', 'makakilo city', 'agaro', 'aloleng', 'husavik', 'miri', 'bilgi', 'bomi', 'novyy urengoy', 'mengcheng', 'himora', 'tianpeng', 'nishihara', 'ejido', 'isangel', 'quatre cocos', 'te anau', 'tall kayf', 'muzhi', 'belmonte', 'bilibino', 'ozernovskiy', 'umzimvubu', 'port hedland', 'praia', 'grindavik', 'nokha', 'satitoa', 'avera', 'urubicha', 'buchanan', 'pitkyaranta', 'prince rupert', 'sorvag', 'holsted', 'mudyuga', 'basoko', 'kununurra', 'kavieng', 'polje', 'bubaque', 'keita', 'pereira barreto', 'fortuna', 'lavrentiya', 'luderitz', 'klaksvik', 'kabinda', 'laguna', 'general roca', 'pyapon', 'walvis bay', 'natal', 'blagoyevo', 'kiruna', 'k ...

# %%
# Create a new data frame
city_data_df = pd.DataFrame()
city_data_df['City'] = ''
city_data_df['Country'] = ''
city_data_df['Lat'] = ''
city_data_df['Lng'] = ''
city_data_df['Max Temp'] = ''
city_data_df['Humidity'] = ''
city_data_df['Cloudiness'] = ''
city_data_df['Wind Speed'] = ''
city_data_df['Current Description'] = ''

city_data_df["City"] = cities

# %%
# Exporting the weather data

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
set_count = 1
record_count = 1
city_data = []

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description" : city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | bredasdorp
# Processing Record 2 of Set 1 | vao
# Processing Record 3 of Set 1 | port alfred
# Processing Record 4 of Set 1 | syava
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 7 of Set 1 | naze
# Processing Record 8 of Set 1 | faanui
# Processing Record 9 of Set 1 | mbanza-ngungu
# Processing Record 10 of Set 1 | fatehgarh churian
# Processing Record 11 of Set 1 | kapaa
# Processing Record 12 of Set 1 | vaini
# Processing Record 13 of Set 1 | coetupo
# City not found. Skipping...
# Processing Record 14 of Set 1 | siocon
# Processing Record 15 of Set 1 | pacific grove
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | half moon bay
# Processing Record 18 of Set 1 | cape town
# Processing Record 19 of Set 1 | saint andrews
# Processing Record 20 of Set 1 | ribeira grande
# Processing Record 21 of Set 1 | batangafo
# Processing Record 22 of Set 1 | beringovskiy
# Processing Record 23 of Set 1 | tasiilaq
# Processing Record 24 of Set 1 | mataura
# Processing Record 25 of Set 1 | busselton
# Processing Record 26 of Set 1 | matara
# Processing Record 27 of Set 1 | vanimo
# Processing Record 28 of Set 1 | yellowknife
# Processing Record 29 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 30 of Set 1 | east london
# Processing Record 31 of Set 1 | wladyslawowo
# Processing Record 32 of Set 1 | saldanha
# Processing Record 33 of Set 1 | hilo
# Processing Record 34 of Set 1 | mount pleasant
# Processing Record 35 of Set 1 | nikolskoye
# Processing Record 36 of Set 1 | rundu
# Processing Record 37 of Set 1 | raudeberg
# Processing Record 38 of Set 1 | barranco
# Processing Record 39 of Set 1 | somerset east
# Processing Record 40 of Set 1 | albany
# Processing Record 41 of Set 1 | ancud
# Processing Record 42 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 43 of Set 1 | dikson
# Processing Record 44 of Set 1 | port keats
# Processing Record 45 of Set 1 | puerto ayora
# Processing Record 46 of Set 1 | kihei
# Processing Record 47 of Set 1 | kenora
# Processing Record 48 of Set 1 | maldonado
# Processing Record 49 of Set 1 | hithadhoo
# Processing Record 50 of Set 1 | saint-philippe
# Processing Record 1 of Set 2 | port lincoln
# Processing Record 2 of Set 2 | asau
# Processing Record 3 of Set 2 | hobart
# Processing Record 4 of Set 2 | mount isa
# Processing Record 5 of Set 2 | seoul
# Processing Record 6 of Set 2 | chuy
# Processing Record 7 of Set 2 | arraial do cabo
# Processing Record 8 of Set 2 | albertville
# Processing Record 9 of Set 2 | gat
# Processing Record 10 of Set 2 | coihaique
# Processing Record 11 of Set 2 | barrow
# Processing Record 12 of Set 2 | kharan
# Processing Record 13 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 14 of Set 2 | timmins
# Processing Record 15 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 2 | cantaura
# Processing Record 17 of Set 2 | dingle
# Processing Record 18 of Set 2 | villazon
# Processing Record 19 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 2 | ponta do sol
# Processing Record 21 of Set 2 | atuona
# Processing Record 22 of Set 2 | georgetown
# Processing Record 23 of Set 2 | sarangani
# Processing Record 24 of Set 2 | upernavik
# Processing Record 25 of Set 2 | san alberto
# Processing Record 26 of Set 2 | cherskiy
# Processing Record 27 of Set 2 | liberty
# Processing Record 28 of Set 2 | kahului
# Processing Record 29 of Set 2 | vallenar
# Processing Record 30 of Set 2 | lyndon
# Processing Record 31 of Set 2 | qandala
# Processing Record 32 of Set 2 | geraldton
# Processing Record 33 of Set 2 | dzaoudzi
# Processing Record 34 of Set 2 | norman wells
# Processing Record 35 of Set 2 | sarila
# Processing Record 36 of Set 2 | concarneau
# Processing Record 37 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 38 of Set 2 | vestmanna
# Processing Record 39 of Set 2 | kavaratti
# Processing Record 40 of Set 2 | mar del plata
# Processing Record 41 of Set 2 | aklavik
# Processing Record 42 of Set 2 | kodiak
# Processing Record 43 of Set 2 | castro
# Processing Record 44 of Set 2 | cidreira
# Processing Record 45 of Set 2 | komsomolskiy
# Processing Record 46 of Set 2 | qaanaaq
# Processing Record 47 of Set 2 | saskylakh
# Processing Record 48 of Set 2 | tiksi
# Processing Record 49 of Set 2 | mahebourg
# Processing Record 50 of Set 2 | saint george
# Processing Record 1 of Set 3 | haverfordwest
# Processing Record 2 of Set 3 | airai
# Processing Record 3 of Set 3 | punta arenas
# Processing Record 4 of Set 3 | ulladulla
# Processing Record 5 of Set 3 | vila franca do campo
# Processing Record 6 of Set 3 | butaritari
# Processing Record 7 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 3 | pamekasan
# Processing Record 9 of Set 3 | krutinka
# Processing Record 10 of Set 3 | carbonia
# Processing Record 11 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 3 | torbay
# Processing Record 14 of Set 3 | zhezkazgan
# Processing Record 15 of Set 3 | lompoc
# Processing Record 16 of Set 3 | karratha
# Processing Record 17 of Set 3 | cap malheureux
# Processing Record 18 of Set 3 | clyde river
# Processing Record 19 of Set 3 | kota bahru
# Processing Record 20 of Set 3 | lehola
# Processing Record 21 of Set 3 | quang ngai
# Processing Record 22 of Set 3 | edd
# Processing Record 23 of Set 3 | barra dos coqueiros
# Processing Record 24 of Set 3 | port hardy
# Processing Record 25 of Set 3 | hermanus
# Processing Record 26 of Set 3 | nanortalik
# Processing Record 27 of Set 3 | guerrero negro
# Processing Record 28 of Set 3 | puerto gaitan
# Processing Record 29 of Set 3 | san andres
# Processing Record 30 of Set 3 | paracuru
# Processing Record 31 of Set 3 | jalu
# Processing Record 32 of Set 3 | ossora
# Processing Record 33 of Set 3 | tangwani
# Processing Record 34 of Set 3 | ust-maya
# Processing Record 35 of Set 3 | new norfolk
# Processing Record 36 of Set 3 | tuktoyaktuk
# Processing Record 37 of Set 3 | mochudi
# Processing Record 38 of Set 3 | badarganj
# Processing Record 39 of Set 3 | madang
# Processing Record 40 of Set 3 | san cristobal
# Processing Record 41 of Set 3 | ilulissat
# Processing Record 42 of Set 3 | bambous virieux
# Processing Record 43 of Set 3 | gorontalo
# Processing Record 44 of Set 3 | dali
# Processing Record 45 of Set 3 | liverpool
# Processing Record 46 of Set 3 | north bend
# Processing Record 47 of Set 3 | bur gabo
# City not found. Skipping...
# Processing Record 48 of Set 3 | atbasar
# Processing Record 49 of Set 3 | tamandare
# Processing Record 50 of Set 3 | severo-kurilsk
# Processing Record 1 of Set 4 | oksfjord
# Processing Record 2 of Set 4 | kryvyy rih
# Processing Record 3 of Set 4 | haines junction
# Processing Record 4 of Set 4 | svetlogorsk
# Processing Record 5 of Set 4 | port elizabeth
# Processing Record 6 of Set 4 | la asuncion
# Processing Record 7 of Set 4 | aswan
# Processing Record 8 of Set 4 | tetiyiv
# Processing Record 9 of Set 4 | coquimbo
# Processing Record 10 of Set 4 | bar harbor
# Processing Record 11 of Set 4 | narsaq
# Processing Record 12 of Set 4 | longyearbyen
# Processing Record 13 of Set 4 | murgab
# Processing Record 14 of Set 4 | kaitangata
# Processing Record 15 of Set 4 | ndioum
# Processing Record 16 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 4 | benghazi
# Processing Record 18 of Set 4 | toulepleu
# City not found. Skipping...
# Processing Record 19 of Set 4 | nakusp
# Processing Record 20 of Set 4 | thinadhoo
# Processing Record 21 of Set 4 | boa vista
# Processing Record 22 of Set 4 | mandalgovi
# Processing Record 23 of Set 4 | buin
# Processing Record 24 of Set 4 | bethel
# Processing Record 25 of Set 4 | cardonal
# Processing Record 26 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 4 | san policarpo
# Processing Record 28 of Set 4 | victoria
# Processing Record 29 of Set 4 | timoteo
# Processing Record 30 of Set 4 | arman
# Processing Record 31 of Set 4 | sivaki
# Processing Record 32 of Set 4 | belyy yar
# Processing Record 33 of Set 4 | yairipok
# Processing Record 34 of Set 4 | tecoanapa
# Processing Record 35 of Set 4 | olavarria
# Processing Record 36 of Set 4 | bluff
# Processing Record 37 of Set 4 | katsiveli
# City not found. Skipping...
# Processing Record 38 of Set 4 | guaruja
# Processing Record 39 of Set 4 | pulandian
# Processing Record 40 of Set 4 | bonaventure
# Processing Record 41 of Set 4 | mamu kanjan
# Processing Record 42 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 43 of Set 4 | chokurdakh
# Processing Record 44 of Set 4 | morant bay
# Processing Record 45 of Set 4 | tilichiki
# Processing Record 46 of Set 4 | nabire
# Processing Record 47 of Set 4 | waingapu
# Processing Record 48 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 50 of Set 4 | wanaka
# Processing Record 1 of Set 5 | bonavista
# Processing Record 2 of Set 5 | farafangana
# Processing Record 3 of Set 5 | kruisfontein
# Processing Record 4 of Set 5 | catamarca
# Processing Record 5 of Set 5 | khatanga
# Processing Record 6 of Set 5 | jamestown
# Processing Record 7 of Set 5 | adwa
# Processing Record 8 of Set 5 | lapy
# Processing Record 9 of Set 5 | sovetskaya gavan
# Processing Record 10 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 11 of Set 5 | banda aceh
# Processing Record 12 of Set 5 | bedford
# Processing Record 13 of Set 5 | sataua
# City not found. Skipping...
# Processing Record 14 of Set 5 | kuvshinovo
# Processing Record 15 of Set 5 | praia da vitoria
# Processing Record 16 of Set 5 | avarua
# Processing Record 17 of Set 5 | amalapuram
# Processing Record 18 of Set 5 | longhua
# Processing Record 19 of Set 5 | bengkulu
# Processing Record 20 of Set 5 | vardo
# Processing Record 21 of Set 5 | guaratuba
# Processing Record 22 of Set 5 | broken hill
# Processing Record 23 of Set 5 | teknaf
# Processing Record 24 of Set 5 | mana
# Processing Record 25 of Set 5 | iacu
# Processing Record 26 of Set 5 | culipapa
# City not found. Skipping...
# Processing Record 27 of Set 5 | evensk
# Processing Record 28 of Set 5 | yulara
# Processing Record 29 of Set 5 | rodrigues alves
# Processing Record 30 of Set 5 | codrington
# Processing Record 31 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 32 of Set 5 | voi
# Processing Record 33 of Set 5 | hendijan
# City not found. Skipping...
# Processing Record 34 of Set 5 | sao joao da barra
# Processing Record 35 of Set 5 | carnarvon
# Processing Record 36 of Set 5 | motygino
# Processing Record 37 of Set 5 | andenes
# Processing Record 38 of Set 5 | iqaluit
# Processing Record 39 of Set 5 | conde
# Processing Record 40 of Set 5 | asbury park
# Processing Record 41 of Set 5 | kurchum
# Processing Record 42 of Set 5 | charlestown
# Processing Record 43 of Set 5 | dicabisagan
# Processing Record 44 of Set 5 | constitucion
# Processing Record 45 of Set 5 | beyneu
# Processing Record 46 of Set 5 | provideniya
# Processing Record 47 of Set 5 | hovd
# Processing Record 48 of Set 5 | sorong
# Processing Record 49 of Set 5 | amapa
# Processing Record 50 of Set 5 | balkhash
# Processing Record 1 of Set 6 | harper
# Processing Record 2 of Set 6 | nanakuli
# Processing Record 3 of Set 6 | namatanai
# Processing Record 4 of Set 6 | cabo san lucas
# Processing Record 5 of Set 6 | pevek
# Processing Record 6 of Set 6 | formosa
# Processing Record 7 of Set 6 | heihe
# Processing Record 8 of Set 6 | baie du tombeau
# City not found. Skipping...
# Processing Record 9 of Set 6 | meulaboh
# Processing Record 10 of Set 6 | roma
# Processing Record 11 of Set 6 | okhotsk
# Processing Record 12 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 13 of Set 6 | bassano
# Processing Record 14 of Set 6 | padang
# Processing Record 15 of Set 6 | makakilo city
# Processing Record 16 of Set 6 | agaro
# Processing Record 17 of Set 6 | aloleng
# Processing Record 18 of Set 6 | husavik
# Processing Record 19 of Set 6 | miri
# Processing Record 20 of Set 6 | bilgi
# Processing Record 21 of Set 6 | bomi
# Processing Record 22 of Set 6 | novyy urengoy
# Processing Record 23 of Set 6 | mengcheng
# Processing Record 24 of Set 6 | himora
# City not found. Skipping...
# Processing Record 25 of Set 6 | tianpeng
# Processing Record 26 of Set 6 | nishihara
# Processing Record 27 of Set 6 | ejido
# Processing Record 28 of Set 6 | isangel
# Processing Record 29 of Set 6 | quatre cocos
# Processing Record 30 of Set 6 | te anau
# Processing Record 31 of Set 6 | tall kayf
# Processing Record 32 of Set 6 | muzhi
# Processing Record 33 of Set 6 | belmonte
# Processing Record 34 of Set 6 | bilibino
# Processing Record 35 of Set 6 | ozernovskiy
# Processing Record 36 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 6 | port hedland
# Processing Record 38 of Set 6 | praia
# Processing Record 39 of Set 6 | grindavik
# Processing Record 40 of Set 6 | nokha
# Processing Record 41 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 42 of Set 6 | avera
# Processing Record 43 of Set 6 | urubicha
# Processing Record 44 of Set 6 | buchanan
# Processing Record 45 of Set 6 | pitkyaranta
# Processing Record 46 of Set 6 | prince rupert
# Processing Record 47 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 48 of Set 6 | holsted
# Processing Record 49 of Set 6 | mudyuga
# City not found. Skipping...
# Processing Record 50 of Set 6 | basoko
# Processing Record 1 of Set 7 | kununurra
# Processing Record 2 of Set 7 | kavieng
# Processing Record 3 of Set 7 | polje
# Processing Record 4 of Set 7 | bubaque
# Processing Record 5 of Set 7 | keita
# Processing Record 6 of Set 7 | pereira barreto
# Processing Record 7 of Set 7 | fortuna
# Processing Record 8 of Set 7 | lavrentiya
# Processing Record 9 of Set 7 | luderitz
# Processing Record 10 of Set 7 | klaksvik
# Processing Record 11 of Set 7 | kabinda
# Processing Record 12 of Set 7 | laguna
# Processing Record 13 of Set 7 | general roca
# Processing Record 14 of Set 7 | pyapon
# Processing Record 15 of Set 7 | walvis bay
# Processing Record 16 of Set 7 | natal
# Processing Record 17 of Set 7 | blagoyevo
# Processing Record 18 of Set 7 | kiruna
# Processing Record 19 of Set 7 | kerteminde
# Processing Record 20 of Set 7 | stonewall
# Processing Record 21 of Set 7 | tabou
# Processing Record 22 of Set 7 | satun
# Processing Record 23 of Set 7 | pariquera-acu
# City not found. Skipping...
# Processing Record 24 of Set 7 | kamenka
# Processing Record 25 of Set 7 | potsdam
# Processing Record 26 of Set 7 | camacha
# Processing Record 27 of Set 7 | alotau
# City not found. Skipping...
# Processing Record 28 of Set 7 | rawson
# Processing Record 29 of Set 7 | esna
# Processing Record 30 of Set 7 | moyale
# Processing Record 31 of Set 7 | puro
# Processing Record 32 of Set 7 | lebu
# Processing Record 33 of Set 7 | hammerfest
# Processing Record 34 of Set 7 | umm lajj
# Processing Record 35 of Set 7 | gao
# Processing Record 36 of Set 7 | marystown
# Processing Record 37 of Set 7 | lazaro cardenas
# Processing Record 38 of Set 7 | soyo
# Processing Record 39 of Set 7 | mastic beach
# Processing Record 40 of Set 7 | baft
# Processing Record 41 of Set 7 | roald
# Processing Record 42 of Set 7 | kamiichi
# Processing Record 43 of Set 7 | ahipara
# Processing Record 44 of Set 7 | barcelos
# Processing Record 45 of Set 7 | turkmenabat
# Processing Record 46 of Set 7 | hami
# Processing Record 47 of Set 7 | ilhabela
# Processing Record 48 of Set 7 | mahon
# Processing Record 49 of Set 7 | biak
# Processing Record 50 of Set 7 | goderich
# Processing Record 1 of Set 8 | taltal
# Processing Record 2 of Set 8 | gawler
# Processing Record 3 of Set 8 | coutances
# Processing Record 4 of Set 8 | moctezuma
# Processing Record 5 of Set 8 | fairbanks
# Processing Record 6 of Set 8 | inirida
# Processing Record 7 of Set 8 | souillac
# Processing Record 8 of Set 8 | isabela
# Processing Record 9 of Set 8 | tevaitoa
# Processing Record 10 of Set 8 | caravelas
# Processing Record 11 of Set 8 | bombay
# Processing Record 12 of Set 8 | onda
# Processing Record 13 of Set 8 | shahrud
# Processing Record 14 of Set 8 | novopokrovka
# Processing Record 15 of Set 8 | kloulklubed
# Processing Record 16 of Set 8 | birao
# Processing Record 17 of Set 8 | batagay-alyta
# Processing Record 18 of Set 8 | esperance
# Processing Record 19 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 8 | hofn
# Processing Record 21 of Set 8 | mackay
# Processing Record 22 of Set 8 | berlevag
# Processing Record 23 of Set 8 | viedma
# Processing Record 24 of Set 8 | hasaki
# Processing Record 25 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 8 | coos bay
# Processing Record 27 of Set 8 | monte escobedo
# Processing Record 28 of Set 8 | biltine
# Processing Record 29 of Set 8 | perene
# Processing Record 30 of Set 8 | qui nhon
# Processing Record 31 of Set 8 | flinders
# Processing Record 32 of Set 8 | baruun-urt
# Processing Record 33 of Set 8 | sitka
# Processing Record 34 of Set 8 | constantine
# Processing Record 35 of Set 8 | kapit
# Processing Record 36 of Set 8 | utiroa
# City not found. Skipping...
# Processing Record 37 of Set 8 | ulaanbaatar
# Processing Record 38 of Set 8 | balkanabat
# Processing Record 39 of Set 8 | olafsvik
# Processing Record 40 of Set 8 | portland
# Processing Record 41 of Set 8 | faya
# Processing Record 42 of Set 8 | mwanza
# Processing Record 43 of Set 8 | dunedin
# Processing Record 44 of Set 8 | phan thiet
# Processing Record 45 of Set 8 | ingham
# Processing Record 46 of Set 8 | vitim
# Processing Record 47 of Set 8 | khash
# Processing Record 48 of Set 8 | nome
# Processing Record 49 of Set 8 | berezovyy
# Processing Record 50 of Set 8 | yurty
# Processing Record 1 of Set 9 | phek
# Processing Record 2 of Set 9 | los llanos de aridane
# Processing Record 3 of Set 9 | phalaborwa
# Processing Record 4 of Set 9 | deputatskiy
# Processing Record 5 of Set 9 | bere
# Processing Record 6 of Set 9 | ilyich
# Processing Record 7 of Set 9 | katsuura
# Processing Record 8 of Set 9 | richards bay
# Processing Record 9 of Set 9 | nouadhibou
# Processing Record 10 of Set 9 | henties bay
# Processing Record 11 of Set 9 | hamilton
# Processing Record 12 of Set 9 | buala
# Processing Record 13 of Set 9 | betlitsa
# Processing Record 14 of Set 9 | zhanaozen
# Processing Record 15 of Set 9 | matamoros
# Processing Record 16 of Set 9 | borujan
# City not found. Skipping...
# Processing Record 17 of Set 9 | thompson
# Processing Record 18 of Set 9 | luau
# Processing Record 19 of Set 9 | bathsheba
# Processing Record 20 of Set 9 | egvekinot
# Processing Record 21 of Set 9 | peniche
# Processing Record 22 of Set 9 | yaan
# Processing Record 23 of Set 9 | acajutla
# Processing Record 24 of Set 9 | rampur hat
# Processing Record 25 of Set 9 | mitzic
# Processing Record 26 of Set 9 | sungai udang
# Processing Record 27 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 28 of Set 9 | jardim
# Processing Record 29 of Set 9 | shchelyayur
# City not found. Skipping...
# Processing Record 30 of Set 9 | saint-augustin
# Processing Record 31 of Set 9 | kurim
# Processing Record 32 of Set 9 | leua
# Processing Record 33 of Set 9 | bilma
# Processing Record 34 of Set 9 | bay roberts
# Processing Record 35 of Set 9 | marigot
# Processing Record 36 of Set 9 | khani
# Processing Record 37 of Set 9 | kenai
# Processing Record 38 of Set 9 | olkhovatka
# Processing Record 39 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 40 of Set 9 | noyabrsk
# Processing Record 41 of Set 9 | mehamn
# Processing Record 42 of Set 9 | dong xoai
# Processing Record 43 of Set 9 | pimentel
# Processing Record 44 of Set 9 | zhigansk
# Processing Record 45 of Set 9 | camopi
# Processing Record 46 of Set 9 | port blair
# Processing Record 47 of Set 9 | songjianghe
# Processing Record 48 of Set 9 | mumford
# Processing Record 49 of Set 9 | jutai
# Processing Record 50 of Set 9 | vila velha
# Processing Record 1 of Set 10 | tautira
# Processing Record 2 of Set 10 | marsa matruh
# Processing Record 3 of Set 10 | chifeng
# Processing Record 4 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 5 of Set 10 | spisske podhradie
# Processing Record 6 of Set 10 | high rock
# Processing Record 7 of Set 10 | nakhon sawan
# Processing Record 8 of Set 10 | fort nelson
# Processing Record 9 of Set 10 | yar-sale
# Processing Record 10 of Set 10 | peterhead
# Processing Record 11 of Set 10 | seymchan
# Processing Record 12 of Set 10 | oistins
# Processing Record 13 of Set 10 | jodhpur
# Processing Record 14 of Set 10 | sao miguel do araguaia
# Processing Record 15 of Set 10 | bolshevik
# Processing Record 16 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 17 of Set 10 | katherine
# Processing Record 18 of Set 10 | daru
# Processing Record 19 of Set 10 | roebourne
# Processing Record 20 of Set 10 | miguelopolis
# Processing Record 21 of Set 10 | tual
# Processing Record 22 of Set 10 | atambua
# Processing Record 23 of Set 10 | do gonbadan
# Processing Record 24 of Set 10 | abu jubayhah
# City not found. Skipping...
# Processing Record 25 of Set 10 | dhidhdhoo
# Processing Record 26 of Set 10 | mackenzie
# Processing Record 27 of Set 10 | jaszbereny
# Processing Record 28 of Set 10 | udachnyy
# Processing Record 29 of Set 10 | ocos
# Processing Record 30 of Set 10 | harlingen
# Processing Record 31 of Set 10 | neon karlovasion
# Processing Record 32 of Set 10 | havre-saint-pierre
# Processing Record 33 of Set 10 | korla
# Processing Record 34 of Set 10 | lagoa
# Processing Record 35 of Set 10 | lugovoy
# Processing Record 36 of Set 10 | luanda
# Processing Record 37 of Set 10 | ola
# Processing Record 38 of Set 10 | namibe
# Processing Record 39 of Set 10 | santiago de cao
# Processing Record 40 of Set 10 | jiwani
# Processing Record 41 of Set 10 | altus
# Processing Record 42 of Set 10 | brae
# Processing Record 43 of Set 10 | pitimbu
# Processing Record 44 of Set 10 | ponnani
# Processing Record 45 of Set 10 | sobolevo
# Processing Record 46 of Set 10 | garden city
# Processing Record 47 of Set 10 | kigoma
# Processing Record 48 of Set 10 | morden
# Processing Record 49 of Set 10 | sumbe
# Processing Record 50 of Set 10 | tasbuget
# City not found. Skipping...
# Processing Record 1 of Set 11 | chara
# Processing Record 2 of Set 11 | bomet
# Processing Record 3 of Set 11 | pangnirtung
# Processing Record 4 of Set 11 | marawi
# Processing Record 5 of Set 11 | talara
# Processing Record 6 of Set 11 | rocha
# Processing Record 7 of Set 11 | benjamin constant
# Processing Record 8 of Set 11 | necochea
# Processing Record 9 of Set 11 | imbituba
# Processing Record 10 of Set 11 | tabuk
# Processing Record 11 of Set 11 | torremolinos
# Processing Record 12 of Set 11 | road town
# Processing Record 13 of Set 11 | challans
# Processing Record 14 of Set 11 | klyuchi
# Processing Record 15 of Set 11 | urfa
# City not found. Skipping...
# Processing Record 16 of Set 11 | oranjemund
# Processing Record 17 of Set 11 | srednekolymsk
# Processing Record 18 of Set 11 | komarikhinskiy
# Processing Record 19 of Set 11 | vestmannaeyjar
# Processing Record 20 of Set 11 | karakulino
# Processing Record 21 of Set 11 | bac lieu
# Processing Record 22 of Set 11 | tancanhuitz
# Processing Record 23 of Set 11 | svetlaya
# Processing Record 24 of Set 11 | san patricio
# Processing Record 25 of Set 11 | camacupa
# Processing Record 26 of Set 11 | finspang
# Processing Record 27 of Set 11 | stepnyak
# Processing Record 28 of Set 11 | senador jose porfirio
# Processing Record 29 of Set 11 | whitehorse
# Processing Record 30 of Set 11 | plettenberg bay
# Processing Record 31 of Set 11 | baykit
# Processing Record 32 of Set 11 | urumqi
# Processing Record 33 of Set 11 | honolulu
# Processing Record 34 of Set 11 | poum
# Processing Record 35 of Set 11 | panguna
# Processing Record 36 of Set 11 | taoudenni
# Processing Record 37 of Set 11 | pisco
# Processing Record 38 of Set 11 | dolores
# Processing Record 39 of Set 11 | chernyshevskiy
# Processing Record 40 of Set 11 | sorland
# Processing Record 41 of Set 11 | aykhal
# Processing Record 42 of Set 11 | yantai
# Processing Record 43 of Set 11 | arlit
# Processing Record 44 of Set 11 | oroville
# Processing Record 45 of Set 11 | tezu
# Processing Record 46 of Set 11 | zandvoort
# Processing Record 47 of Set 11 | maine-soroa
# Processing Record 48 of Set 11 | riyadh
# Processing Record 49 of Set 11 | prado
# Processing Record 50 of Set 11 | maniitsoq
# Processing Record 1 of Set 12 | baghdad
# Processing Record 2 of Set 12 | la ronge
# Processing Record 3 of Set 12 | old orchard beach
# Processing Record 4 of Set 12 | pangkalanbuun
# Processing Record 5 of Set 12 | la plata
# Processing Record 6 of Set 12 | sai buri
# Processing Record 7 of Set 12 | cayenne
# Processing Record 8 of Set 12 | kingman
# Processing Record 9 of Set 12 | ocampo
# Processing Record 10 of Set 12 | shingu
# Processing Record 11 of Set 12 | prescott
# Processing Record 12 of Set 12 | ambon
# Processing Record 13 of Set 12 | san carlos
# Processing Record 14 of Set 12 | joshimath
# Processing Record 15 of Set 12 | neuquen
# Processing Record 16 of Set 12 | sao sebastiao
# Processing Record 17 of Set 12 | mogadishu
# Processing Record 18 of Set 12 | uthal
# Processing Record 19 of Set 12 | solhan
# Processing Record 20 of Set 12 | jieshi
# Processing Record 21 of Set 12 | caruray
# Processing Record 22 of Set 12 | cajuru
# Processing Record 23 of Set 12 | lumeje
# Processing Record 24 of Set 12 | tuatapere
# Processing Record 25 of Set 12 | pangody
# Processing Record 26 of Set 12 | lorient
# Processing Record 27 of Set 12 | hay river
# Processing Record 28 of Set 12 | sheboygan
# Processing Record 29 of Set 12 | ariquemes
# Processing Record 30 of Set 12 | ullapool
# Processing Record 31 of Set 12 | zarechnyy
# Processing Record 32 of Set 12 | lysva
# Processing Record 33 of Set 12 | dudinka
# Processing Record 34 of Set 12 | balad
# Processing Record 35 of Set 12 | am timan
# Processing Record 36 of Set 12 | sokoni
# Processing Record 37 of Set 12 | zambezi
# Processing Record 38 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 39 of Set 12 | sao filipe
# Processing Record 40 of Set 12 | champaign
# Processing Record 41 of Set 12 | gaozhou
# Processing Record 42 of Set 12 | touros
# Processing Record 43 of Set 12 | tahta
# Processing Record 44 of Set 12 | itaquyry
# Processing Record 45 of Set 12 | linares
# Processing Record 46 of Set 12 | ufimskiy
# Processing Record 47 of Set 12 | kuhdasht
# Processing Record 48 of Set 12 | westport
# Processing Record 49 of Set 12 | pinhao
# Processing Record 50 of Set 12 | marinette
# Processing Record 1 of Set 13 | anqiu
# Processing Record 2 of Set 13 | kiama
# Processing Record 3 of Set 13 | saint-francois
# Processing Record 4 of Set 13 | huicungo
# Processing Record 5 of Set 13 | saravan
# Processing Record 6 of Set 13 | awbari
# Processing Record 7 of Set 13 | magadan
# Processing Record 8 of Set 13 | ambulu
# Processing Record 9 of Set 13 | alice springs
# Processing Record 10 of Set 13 | solnechnyy
# Processing Record 11 of Set 13 | rawlins
# Processing Record 12 of Set 13 | coshocton
# Processing Record 13 of Set 13 | talesh
# City not found. Skipping...
# Processing Record 14 of Set 13 | chapais
# Processing Record 15 of Set 13 | linfen
# Processing Record 16 of Set 13 | coromandel
# Processing Record 17 of Set 13 | tadine
# Processing Record 18 of Set 13 | labuhan
# Processing Record 19 of Set 13 | celestun
# Processing Record 20 of Set 13 | bonfim
# Processing Record 21 of Set 13 | noumea
# Processing Record 22 of Set 13 | severnoye
# Processing Record 23 of Set 13 | beeville
# Processing Record 24 of Set 13 | neiafu
# Processing Record 25 of Set 13 | halacho
# Processing Record 26 of Set 13 | inhambane
# Processing Record 27 of Set 13 | curup
# Processing Record 28 of Set 13 | hambantota
# Processing Record 29 of Set 13 | port said
# Processing Record 30 of Set 13 | atar
# Processing Record 31 of Set 13 | diffa
# Processing Record 32 of Set 13 | klimovo
# Processing Record 33 of Set 13 | katangli
# Processing Record 34 of Set 13 | leningradskiy
# Processing Record 35 of Set 13 | ust-kut
# Processing Record 36 of Set 13 | buraydah
# Processing Record 37 of Set 13 | itarema
# Processing Record 38 of Set 13 | dubovka
# Processing Record 39 of Set 13 | tutoia
# Processing Record 40 of Set 13 | albury
# Processing Record 41 of Set 13 | culebra
# Processing Record 42 of Set 13 | raymondville
# Processing Record 43 of Set 13 | serik
# Processing Record 44 of Set 13 | rio gallegos
# Processing Record 45 of Set 13 | moose factory
# Processing Record 46 of Set 13 | samarai
# Processing Record 47 of Set 13 | biloela
# Processing Record 48 of Set 13 | senaki
# Processing Record 49 of Set 13 | grand gaube
# Processing Record 50 of Set 13 | banloc
# Processing Record 1 of Set 14 | caxambu
# Processing Record 2 of Set 14 | quila
# Processing Record 3 of Set 14 | benicarlo
# Processing Record 4 of Set 14 | gangotri
# City not found. Skipping...
# Processing Record 5 of Set 14 | lensk
# Processing Record 6 of Set 14 | eureka
# Processing Record 7 of Set 14 | kondinskoye
# Processing Record 8 of Set 14 | alofi
# Processing Record 9 of Set 14 | duldurga
# Processing Record 10 of Set 14 | oriximina
# Processing Record 11 of Set 14 | adjumani
# Processing Record 12 of Set 14 | bolshoye murashkino
# Processing Record 13 of Set 14 | ndjole
# Processing Record 14 of Set 14 | meybod
# Processing Record 15 of Set 14 | kawalu
# Processing Record 16 of Set 14 | jumla
# Processing Record 17 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 18 of Set 14 | douglas
# Processing Record 19 of Set 14 | huilong
# Processing Record 20 of Set 14 | malinovoye ozero
# Processing Record 21 of Set 14 | tungkang
# City not found. Skipping...
# Processing Record 22 of Set 14 | andapa
# Processing Record 23 of Set 14 | palmer
# Processing Record 24 of Set 14 | vostok
# Processing Record 25 of Set 14 | chapadinha
# Processing Record 26 of Set 14 | smolenka
# Processing Record 27 of Set 14 | umm kaddadah
# Processing Record 28 of Set 14 | kattivakkam
# Processing Record 29 of Set 14 | nchelenge
# Processing Record 30 of Set 14 | college
# Processing Record 31 of Set 14 | poquoson
# Processing Record 32 of Set 14 | rudbar
# Processing Record 33 of Set 14 | port hawkesbury
# Processing Record 34 of Set 14 | muscat
# Processing Record 35 of Set 14 | moron
# Processing Record 36 of Set 14 | provost
# Processing Record 37 of Set 14 | santa maria
# Processing Record 38 of Set 14 | paamiut
# Processing Record 39 of Set 14 | brownwood
# Processing Record 40 of Set 14 | monrovia
# Processing Record 41 of Set 14 | sombrerete
# Processing Record 42 of Set 14 | lengshuitan
# Processing Record 43 of Set 14 | tres lagoas
# Processing Record 44 of Set 14 | ayagoz
# Processing Record 45 of Set 14 | adrar
# Processing Record 46 of Set 14 | tura
# Processing Record 47 of Set 14 | manado
# Processing Record 48 of Set 14 | wewak
# Processing Record 49 of Set 14 | richard toll
# City not found. Skipping...
# Processing Record 50 of Set 14 | quartucciu
# Processing Record 1 of Set 15 | amargosa
# Processing Record 2 of Set 15 | sambava
# Processing Record 3 of Set 15 | ust-tsilma
# Processing Record 4 of Set 15 | karatuzskoye
# Processing Record 5 of Set 15 | myanaung
# Processing Record 6 of Set 15 | iralaya
# Processing Record 7 of Set 15 | anito
# Processing Record 8 of Set 15 | dicamay
# Processing Record 9 of Set 15 | rabo de peixe
# Processing Record 10 of Set 15 | kirovskiy
# Processing Record 11 of Set 15 | maler kotla
# Processing Record 12 of Set 15 | nueva imperial
# Processing Record 13 of Set 15 | juazeiro
# Processing Record 14 of Set 15 | luangwa
# Processing Record 15 of Set 15 | roswell
# Processing Record 16 of Set 15 | tunduma
# Processing Record 17 of Set 15 | moree
# Processing Record 18 of Set 15 | shelburne
# Processing Record 19 of Set 15 | palu
# Processing Record 20 of Set 15 | havoysund
# Processing Record 21 of Set 15 | dubrovytsya
# Processing Record 22 of Set 15 | markova
# Processing Record 23 of Set 15 | pringsewu
# Processing Record 24 of Set 15 | rio grande
# Processing Record 25 of Set 15 | kahuta
# Processing Record 26 of Set 15 | hailar
# Processing Record 27 of Set 15 | praya
# Processing Record 28 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 29 of Set 15 | kaeo
# Processing Record 30 of Set 15 | port macquarie
# Processing Record 31 of Set 15 | derzhavinsk
# Processing Record 32 of Set 15 | golden rock
# City not found. Skipping...
# Processing Record 33 of Set 15 | camotan
# Processing Record 34 of Set 15 | timizart
# Processing Record 35 of Set 15 | sola
# Processing Record 36 of Set 15 | muzquiz
# City not found. Skipping...
# Processing Record 37 of Set 15 | gudalur
# Processing Record 38 of Set 15 | roberval
# Processing Record 39 of Set 15 | nieuw nickerie
# Processing Record 40 of Set 15 | nemuro
# Processing Record 41 of Set 15 | moshenskoye
# Processing Record 42 of Set 15 | kralendijk
# Processing Record 43 of Set 15 | giyani
# Processing Record 44 of Set 15 | santa cruz del sur
# Processing Record 45 of Set 15 | pokhara
# Processing Record 46 of Set 15 | veraval
# Processing Record 47 of Set 15 | inuvik
# Processing Record 48 of Set 15 | mastic
# Processing Record 49 of Set 15 | cabedelo
# Processing Record 50 of Set 15 | rotnes
# Processing Record 1 of Set 16 | bandarbeyla
# Processing Record 2 of Set 16 | najran
# Processing Record 3 of Set 16 | kodinsk
# Processing Record 4 of Set 16 | moerai
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Bredasdorp      ZA -34.5322   20.0403     54.72        87          25
# 1            Vao      NC -22.6667  167.4833     74.21        64         100
# 2    Port Alfred      ZA -33.5906   26.8910     59.18        83          95
# 3          Syava      RU  58.0146   46.3222     44.22        90          96
# 4        Ushuaia      AR -54.8000  -68.3000     44.26        70          75
# ..           ...     ...      ...       ...       ...       ...         ...
# 695       Rotnes      NO  60.0571   10.8614     44.35        55          15
# 696  Bandarbeyla      SO   9.4942   50.8122     81.81        73           6
# 697       Najran      SA  17.4924   44.1277     79.45        38          62
# 698      Kodinsk      RU  58.6881   99.1844     21.34        97          97
# 699       Moerai      PF -22.4333 -151.3333     78.08        73          41
#
#      Wind Speed Current Description
# 0          4.76          light rain
# 1         23.80     overcast clouds
# 2          1.99     overcast clouds
# 3          6.53     overcast clouds
# 4          6.91       broken clouds
# ..          ...                 ...
# 695        4.90          few clouds
# 696       11.30           clear sky
# 697       11.65       broken clouds
# 698        3.11     overcast clouds
# 699       19.66    scattered clouds
#
# [700 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
