# %%
# Import the dependencies
import pandas as pd
import numpy as np
import matplotlib as plt
from citipy import citipy
import requests
from config import weather_api_key
from datetime import datetime
import time

# %%
# Create a new set of 2,000 random latitudes and longitudes
latitudes = np.random.uniform(90,-90,2000)
longitudes = np.random.uniform(180,-180,2000)
lat_lng = zip(latitudes,longitudes)
coordinates = list(lat_lng)
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    if city not in cities:
        cities.append(city)

print(cities)
# Out:
# ['rikitea', 'hermanus', 'thompson', 'punta arenas', 'hobart', 'tual', 'karratha', 'muroto', 'jalu', 'amderma', 'mataura', 'kapaa', 'ushuaia', 'tomatlan', 'tanete', 'wanning', 'jamestown', 'salalah', 'atuona', 'vaini', 'iranshahr', 'arraial do cabo', 'arlit', 'isangel', 'caravelas', 'sioux lookout', 'saint george', 'aljezur', 'san cristobal', 'esperance', 'mar del plata', 'gorontalo', 'cidreira', 'taolanaro', 'kirksville', 'cape town', 'bluff', 'sao filipe', 'caceres', 'mercedes', 'marystown', 'torbay', 'hilo', 'belushya guba', 'kavieng', 'east london', 'porto walter', 'lata', 'hithadhoo', 'provideniya', 'butaritari', 'takoradi', 'ust-tsilma', 'tumannyy', 'avarua', 'grand river south east', 'beringovskiy', 'albany', 'chuy', 'el faiyum', 'puerto leguizamo', 'busselton', 'sibenik', 'kandava', 'maragogi', 'kavaratti', 'khatanga', 'new norfolk', 'severnoye', 'puerto ayora', 'casselman', 'port alfred', 'preobrazheniye', 'talnakh', 'zinder', 'klaksvik', 'halifax', 'saskylakh', 'dryden', 'vestmanna', 'longyan', 'dikson', 'constitucion', 'chumikan', 'cedar city', 'geraldton', 'banagher', 'bargal', 'lebu', 'noyon', 'lavrentiya', 'chokurdakh', 'nizhneyansk', 'wanaka', 'tabialan', 'doha', 'flinders', 'gillette', 'quesnel', 'longyearbyen', 'the hammocks', 'bredasdorp', 'sinnamary', 'castro', 'rio gallegos', 'clyde river', 'nuuk', 'illoqqortoormiut', 'dingle', 'kishtwar', 'pangkalanbuun', 'yertsevo', 'the valley', 'qandala', 'santa rosa', 'hofn', 'betafo', 'airai', 'brasilia de minas', 'bethel', 'vysokogornyy', 'souillac', 'coihaique', 'lorengau', 'okhotsk', 'codrington', 'vila franca do campo', 'nikolskoye', 'balkhash', 'ajdabiya', 'sur', 'gisborne', 'alice springs', 'tazovskiy', 'letlhakane', 'suntar', 'xinyu', 'cabo san lucas', 'camocim', 'douglas', 'te anau', 'liverpool', 'qaanaaq', 'bilibino', 'megion', 'sorland', 'fort nelson', 'chapais', 'belyy yar', 'zhezkazgan', 'poum', 'freetown', 'cayenne', 'attawapiskat', 'ancud', 'palu', 'mount gambier', 'guaraniacu', 'bandrele', 'upata', 'san angelo', 'barentsburg', 'ascension', 'gniezno', 'luohe', 'nanpara', 'mahebourg', 'sansai', 'anadyr', 'faranah', 'sataua', 'kaeo', 'ludvika', 'xapuri', 'nanortalik', 'meulaboh', 'peniche', 'tasiilaq', 'sao miguel do iguacu', 'manono', 'rio tercero', 'ribeira grande', 'port hedland', 'beisfjord', 'ust-kuyga', 'santiago de cao', 'saint-francois', 'kaitangata', 'njombe', 'granville', 'thalassery', 'coahuayana', 'manokwari', 'yerbogachen', 'hasaki', 'donghai', 'cherskiy', 'mys shmidta', 'vostok', 'tidore', 'san quintin', 'luena', 'aklavik', 'yellowknife', 'barrow', 'mananara', 'vardo', 'roma', 'georgetown', 'muros', 'linhares', 'ocampo', 'camopi', 'rungata', 'kudahuvadhoo', 'kamenskoye', 'laguna', 'yayva', 'haines junction', 'nouadhibou', 'tiksi', 'adamas', 'mouila', 'saint-philippe', 'norrtalje', 'faanui', 'montelibano', 'berlevag', 'mata', 'alpena', 'santiago', 'umm lajj', 'pemba', 'port elizabeth', 'tuktoyaktuk', 'nacala', 'rivadavia', 'asahikawa', 'nome', 'vila velha', 'burns lake', 'kruisfontein', 'camacha', 'alugan', 'kyaiklat', 'ponta do sol', 'benghazi', 'college', 'patnos', 'phalombe', 'aasiaat', 'byron bay', 'puerto del rosario', 'narsaq', 'imeni poliny osipenko', 'deputatskiy', 'salinopolis', 'xuanhua', 'tongliao', 'urengoy', 'cockburn town', 'tawkar', 'noumea', 'luderitz', 'balkanabat', 'namatanai', 'avera', 'severo-kurilsk', 'nador', 'ugoofaaru', 'abu dhabi', 'paka', 'sola', 'eregli', 'yala', 'altamira', 'kodiak', 'bud', 'mitzic', 'hohhot', 'phan rang', 'galle', 'barreirinha', 'maraa', 'jati', 'upernavik', 'fortuna', 'norman wells', 'santa ana', 'riyadh', 'katsuura', 'port lavaca', 'pevek', 'vaitupu', 'miri', 'honiara', 'saleaula', 'atambua', 'hualmay', 'cosala', 'altamont', 'atar', 'sao jose da coroa grande', 'guanica', 'shingu', 'agadez', 'marsa matruh', 'independence', 'ankazoabo', 'okha', 'lompoc', 'malwan', 'tsihombe', 'ombessa', 'bata', 'richards bay', 'kuusamo', 'bolu', 'bokspits', 'mimoso do sul', 'voh', 'kalangala', 'oistins', 'bathsheba' ...

# %%
# Create a new data frame
city_data_df = pd.DataFrame()
city_data_df['City'] = ''
city_data_df['Country'] = ''
city_data_df['Lat'] = ''
city_data_df['Lng'] = ''
city_data_df['Max Temp'] = ''
city_data_df['Humidity'] = ''
city_data_df['Cloudiness'] = ''
city_data_df['Wind Speed'] = ''
city_data_df['Current Description'] = ''

city_data_df["City"] = cities

# %%
# Exporting the weather data

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
set_count = 1
record_count = 1
city_data = []

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description" : city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | thompson
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | hobart
# Processing Record 6 of Set 1 | tual
# Processing Record 7 of Set 1 | karratha
# Processing Record 8 of Set 1 | muroto
# Processing Record 9 of Set 1 | jalu
# Processing Record 10 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | kapaa
# Processing Record 13 of Set 1 | ushuaia
# Processing Record 14 of Set 1 | tomatlan
# Processing Record 15 of Set 1 | tanete
# Processing Record 16 of Set 1 | wanning
# Processing Record 17 of Set 1 | jamestown
# Processing Record 18 of Set 1 | salalah
# Processing Record 19 of Set 1 | atuona
# Processing Record 20 of Set 1 | vaini
# Processing Record 21 of Set 1 | iranshahr
# Processing Record 22 of Set 1 | arraial do cabo
# Processing Record 23 of Set 1 | arlit
# Processing Record 24 of Set 1 | isangel
# Processing Record 25 of Set 1 | caravelas
# Processing Record 26 of Set 1 | sioux lookout
# Processing Record 27 of Set 1 | saint george
# Processing Record 28 of Set 1 | aljezur
# Processing Record 29 of Set 1 | san cristobal
# Processing Record 30 of Set 1 | esperance
# Processing Record 31 of Set 1 | mar del plata
# Processing Record 32 of Set 1 | gorontalo
# Processing Record 33 of Set 1 | cidreira
# Processing Record 34 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 35 of Set 1 | kirksville
# Processing Record 36 of Set 1 | cape town
# Processing Record 37 of Set 1 | bluff
# Processing Record 38 of Set 1 | sao filipe
# Processing Record 39 of Set 1 | caceres
# Processing Record 40 of Set 1 | mercedes
# Processing Record 41 of Set 1 | marystown
# Processing Record 42 of Set 1 | torbay
# Processing Record 43 of Set 1 | hilo
# Processing Record 44 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 45 of Set 1 | kavieng
# Processing Record 46 of Set 1 | east london
# Processing Record 47 of Set 1 | porto walter
# Processing Record 48 of Set 1 | lata
# Processing Record 49 of Set 1 | hithadhoo
# Processing Record 50 of Set 1 | provideniya
# Processing Record 1 of Set 2 | butaritari
# Processing Record 2 of Set 2 | takoradi
# Processing Record 3 of Set 2 | ust-tsilma
# Processing Record 4 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 2 | avarua
# Processing Record 6 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 2 | beringovskiy
# Processing Record 8 of Set 2 | albany
# Processing Record 9 of Set 2 | chuy
# Processing Record 10 of Set 2 | el faiyum
# City not found. Skipping...
# Processing Record 11 of Set 2 | puerto leguizamo
# Processing Record 12 of Set 2 | busselton
# Processing Record 13 of Set 2 | sibenik
# Processing Record 14 of Set 2 | kandava
# Processing Record 15 of Set 2 | maragogi
# Processing Record 16 of Set 2 | kavaratti
# Processing Record 17 of Set 2 | khatanga
# Processing Record 18 of Set 2 | new norfolk
# Processing Record 19 of Set 2 | severnoye
# Processing Record 20 of Set 2 | puerto ayora
# Processing Record 21 of Set 2 | casselman
# Processing Record 22 of Set 2 | port alfred
# Processing Record 23 of Set 2 | preobrazheniye
# Processing Record 24 of Set 2 | talnakh
# Processing Record 25 of Set 2 | zinder
# Processing Record 26 of Set 2 | klaksvik
# Processing Record 27 of Set 2 | halifax
# Processing Record 28 of Set 2 | saskylakh
# Processing Record 29 of Set 2 | dryden
# Processing Record 30 of Set 2 | vestmanna
# Processing Record 31 of Set 2 | longyan
# Processing Record 32 of Set 2 | dikson
# Processing Record 33 of Set 2 | constitucion
# Processing Record 34 of Set 2 | chumikan
# Processing Record 35 of Set 2 | cedar city
# Processing Record 36 of Set 2 | geraldton
# Processing Record 37 of Set 2 | banagher
# Processing Record 38 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 39 of Set 2 | lebu
# Processing Record 40 of Set 2 | noyon
# Processing Record 41 of Set 2 | lavrentiya
# Processing Record 42 of Set 2 | chokurdakh
# Processing Record 43 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 2 | wanaka
# Processing Record 45 of Set 2 | tabialan
# City not found. Skipping...
# Processing Record 46 of Set 2 | doha
# Processing Record 47 of Set 2 | flinders
# Processing Record 48 of Set 2 | gillette
# Processing Record 49 of Set 2 | quesnel
# Processing Record 50 of Set 2 | longyearbyen
# Processing Record 1 of Set 3 | the hammocks
# Processing Record 2 of Set 3 | bredasdorp
# Processing Record 3 of Set 3 | sinnamary
# Processing Record 4 of Set 3 | castro
# Processing Record 5 of Set 3 | rio gallegos
# Processing Record 6 of Set 3 | clyde river
# Processing Record 7 of Set 3 | nuuk
# Processing Record 8 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 9 of Set 3 | dingle
# Processing Record 10 of Set 3 | kishtwar
# Processing Record 11 of Set 3 | pangkalanbuun
# Processing Record 12 of Set 3 | yertsevo
# Processing Record 13 of Set 3 | the valley
# Processing Record 14 of Set 3 | qandala
# Processing Record 15 of Set 3 | santa rosa
# Processing Record 16 of Set 3 | hofn
# Processing Record 17 of Set 3 | betafo
# Processing Record 18 of Set 3 | airai
# Processing Record 19 of Set 3 | brasilia de minas
# Processing Record 20 of Set 3 | bethel
# Processing Record 21 of Set 3 | vysokogornyy
# Processing Record 22 of Set 3 | souillac
# Processing Record 23 of Set 3 | coihaique
# Processing Record 24 of Set 3 | lorengau
# Processing Record 25 of Set 3 | okhotsk
# Processing Record 26 of Set 3 | codrington
# Processing Record 27 of Set 3 | vila franca do campo
# Processing Record 28 of Set 3 | nikolskoye
# Processing Record 29 of Set 3 | balkhash
# Processing Record 30 of Set 3 | ajdabiya
# Processing Record 31 of Set 3 | sur
# Processing Record 32 of Set 3 | gisborne
# Processing Record 33 of Set 3 | alice springs
# Processing Record 34 of Set 3 | tazovskiy
# Processing Record 35 of Set 3 | letlhakane
# Processing Record 36 of Set 3 | suntar
# Processing Record 37 of Set 3 | xinyu
# Processing Record 38 of Set 3 | cabo san lucas
# Processing Record 39 of Set 3 | camocim
# Processing Record 40 of Set 3 | douglas
# Processing Record 41 of Set 3 | te anau
# Processing Record 42 of Set 3 | liverpool
# Processing Record 43 of Set 3 | qaanaaq
# Processing Record 44 of Set 3 | bilibino
# Processing Record 45 of Set 3 | megion
# Processing Record 46 of Set 3 | sorland
# Processing Record 47 of Set 3 | fort nelson
# Processing Record 48 of Set 3 | chapais
# Processing Record 49 of Set 3 | belyy yar
# Processing Record 50 of Set 3 | zhezkazgan
# Processing Record 1 of Set 4 | poum
# Processing Record 2 of Set 4 | freetown
# Processing Record 3 of Set 4 | cayenne
# Processing Record 4 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 5 of Set 4 | ancud
# Processing Record 6 of Set 4 | palu
# Processing Record 7 of Set 4 | mount gambier
# Processing Record 8 of Set 4 | guaraniacu
# Processing Record 9 of Set 4 | bandrele
# Processing Record 10 of Set 4 | upata
# Processing Record 11 of Set 4 | san angelo
# Processing Record 12 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 4 | ascension
# Processing Record 14 of Set 4 | gniezno
# Processing Record 15 of Set 4 | luohe
# Processing Record 16 of Set 4 | nanpara
# Processing Record 17 of Set 4 | mahebourg
# Processing Record 18 of Set 4 | sansai
# City not found. Skipping...
# Processing Record 19 of Set 4 | anadyr
# Processing Record 20 of Set 4 | faranah
# Processing Record 21 of Set 4 | sataua
# City not found. Skipping...
# Processing Record 22 of Set 4 | kaeo
# Processing Record 23 of Set 4 | ludvika
# Processing Record 24 of Set 4 | xapuri
# Processing Record 25 of Set 4 | nanortalik
# Processing Record 26 of Set 4 | meulaboh
# Processing Record 27 of Set 4 | peniche
# Processing Record 28 of Set 4 | tasiilaq
# Processing Record 29 of Set 4 | sao miguel do iguacu
# Processing Record 30 of Set 4 | manono
# Processing Record 31 of Set 4 | rio tercero
# Processing Record 32 of Set 4 | ribeira grande
# Processing Record 33 of Set 4 | port hedland
# Processing Record 34 of Set 4 | beisfjord
# Processing Record 35 of Set 4 | ust-kuyga
# Processing Record 36 of Set 4 | santiago de cao
# Processing Record 37 of Set 4 | saint-francois
# Processing Record 38 of Set 4 | kaitangata
# Processing Record 39 of Set 4 | njombe
# Processing Record 40 of Set 4 | granville
# Processing Record 41 of Set 4 | thalassery
# Processing Record 42 of Set 4 | coahuayana
# Processing Record 43 of Set 4 | manokwari
# Processing Record 44 of Set 4 | yerbogachen
# Processing Record 45 of Set 4 | hasaki
# Processing Record 46 of Set 4 | donghai
# Processing Record 47 of Set 4 | cherskiy
# Processing Record 48 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 4 | vostok
# Processing Record 50 of Set 4 | tidore
# City not found. Skipping...
# Processing Record 1 of Set 5 | san quintin
# Processing Record 2 of Set 5 | luena
# Processing Record 3 of Set 5 | aklavik
# Processing Record 4 of Set 5 | yellowknife
# Processing Record 5 of Set 5 | barrow
# Processing Record 6 of Set 5 | mananara
# Processing Record 7 of Set 5 | vardo
# Processing Record 8 of Set 5 | roma
# Processing Record 9 of Set 5 | georgetown
# Processing Record 10 of Set 5 | muros
# Processing Record 11 of Set 5 | linhares
# Processing Record 12 of Set 5 | ocampo
# Processing Record 13 of Set 5 | camopi
# Processing Record 14 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 15 of Set 5 | kudahuvadhoo
# Processing Record 16 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 17 of Set 5 | laguna
# Processing Record 18 of Set 5 | yayva
# Processing Record 19 of Set 5 | haines junction
# Processing Record 20 of Set 5 | nouadhibou
# Processing Record 21 of Set 5 | tiksi
# Processing Record 22 of Set 5 | adamas
# Processing Record 23 of Set 5 | mouila
# Processing Record 24 of Set 5 | saint-philippe
# Processing Record 25 of Set 5 | norrtalje
# Processing Record 26 of Set 5 | faanui
# Processing Record 27 of Set 5 | montelibano
# Processing Record 28 of Set 5 | berlevag
# Processing Record 29 of Set 5 | mata
# Processing Record 30 of Set 5 | alpena
# Processing Record 31 of Set 5 | santiago
# Processing Record 32 of Set 5 | umm lajj
# Processing Record 33 of Set 5 | pemba
# Processing Record 34 of Set 5 | port elizabeth
# Processing Record 35 of Set 5 | tuktoyaktuk
# Processing Record 36 of Set 5 | nacala
# Processing Record 37 of Set 5 | rivadavia
# Processing Record 38 of Set 5 | asahikawa
# Processing Record 39 of Set 5 | nome
# Processing Record 40 of Set 5 | vila velha
# Processing Record 41 of Set 5 | burns lake
# Processing Record 42 of Set 5 | kruisfontein
# Processing Record 43 of Set 5 | camacha
# Processing Record 44 of Set 5 | alugan
# Processing Record 45 of Set 5 | kyaiklat
# Processing Record 46 of Set 5 | ponta do sol
# Processing Record 47 of Set 5 | benghazi
# Processing Record 48 of Set 5 | college
# Processing Record 49 of Set 5 | patnos
# Processing Record 50 of Set 5 | phalombe
# Processing Record 1 of Set 6 | aasiaat
# Processing Record 2 of Set 6 | byron bay
# Processing Record 3 of Set 6 | puerto del rosario
# Processing Record 4 of Set 6 | narsaq
# Processing Record 5 of Set 6 | imeni poliny osipenko
# Processing Record 6 of Set 6 | deputatskiy
# Processing Record 7 of Set 6 | salinopolis
# Processing Record 8 of Set 6 | xuanhua
# Processing Record 9 of Set 6 | tongliao
# Processing Record 10 of Set 6 | urengoy
# Processing Record 11 of Set 6 | cockburn town
# Processing Record 12 of Set 6 | tawkar
# City not found. Skipping...
# Processing Record 13 of Set 6 | noumea
# Processing Record 14 of Set 6 | luderitz
# Processing Record 15 of Set 6 | balkanabat
# Processing Record 16 of Set 6 | namatanai
# Processing Record 17 of Set 6 | avera
# Processing Record 18 of Set 6 | severo-kurilsk
# Processing Record 19 of Set 6 | nador
# Processing Record 20 of Set 6 | ugoofaaru
# Processing Record 21 of Set 6 | abu dhabi
# Processing Record 22 of Set 6 | paka
# Processing Record 23 of Set 6 | sola
# Processing Record 24 of Set 6 | eregli
# Processing Record 25 of Set 6 | yala
# Processing Record 26 of Set 6 | altamira
# Processing Record 27 of Set 6 | kodiak
# Processing Record 28 of Set 6 | bud
# Processing Record 29 of Set 6 | mitzic
# Processing Record 30 of Set 6 | hohhot
# Processing Record 31 of Set 6 | phan rang
# City not found. Skipping...
# Processing Record 32 of Set 6 | galle
# Processing Record 33 of Set 6 | barreirinha
# Processing Record 34 of Set 6 | maraa
# Processing Record 35 of Set 6 | jati
# Processing Record 36 of Set 6 | upernavik
# Processing Record 37 of Set 6 | fortuna
# Processing Record 38 of Set 6 | norman wells
# Processing Record 39 of Set 6 | santa ana
# Processing Record 40 of Set 6 | riyadh
# Processing Record 41 of Set 6 | katsuura
# Processing Record 42 of Set 6 | port lavaca
# Processing Record 43 of Set 6 | pevek
# Processing Record 44 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 6 | miri
# Processing Record 46 of Set 6 | honiara
# Processing Record 47 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 6 | atambua
# Processing Record 49 of Set 6 | hualmay
# Processing Record 50 of Set 6 | cosala
# Processing Record 1 of Set 7 | altamont
# Processing Record 2 of Set 7 | atar
# Processing Record 3 of Set 7 | sao jose da coroa grande
# Processing Record 4 of Set 7 | guanica
# Processing Record 5 of Set 7 | shingu
# Processing Record 6 of Set 7 | agadez
# Processing Record 7 of Set 7 | marsa matruh
# Processing Record 8 of Set 7 | independence
# Processing Record 9 of Set 7 | ankazoabo
# Processing Record 10 of Set 7 | okha
# Processing Record 11 of Set 7 | lompoc
# Processing Record 12 of Set 7 | malwan
# City not found. Skipping...
# Processing Record 13 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 7 | ombessa
# Processing Record 15 of Set 7 | bata
# Processing Record 16 of Set 7 | richards bay
# Processing Record 17 of Set 7 | kuusamo
# Processing Record 18 of Set 7 | bolu
# Processing Record 19 of Set 7 | bokspits
# City not found. Skipping...
# Processing Record 20 of Set 7 | mimoso do sul
# Processing Record 21 of Set 7 | voh
# Processing Record 22 of Set 7 | kalangala
# Processing Record 23 of Set 7 | oistins
# Processing Record 24 of Set 7 | bathsheba
# Processing Record 25 of Set 7 | katobu
# Processing Record 26 of Set 7 | rocha
# Processing Record 27 of Set 7 | sabang
# Processing Record 28 of Set 7 | buraydah
# Processing Record 29 of Set 7 | almeria
# Processing Record 30 of Set 7 | pisco
# Processing Record 31 of Set 7 | beloha
# Processing Record 32 of Set 7 | naze
# Processing Record 33 of Set 7 | umm ruwabah
# City not found. Skipping...
# Processing Record 34 of Set 7 | hengyang
# Processing Record 35 of Set 7 | batagay-alyta
# Processing Record 36 of Set 7 | bengkulu
# Processing Record 37 of Set 7 | muhoroni
# Processing Record 38 of Set 7 | chipinge
# Processing Record 39 of Set 7 | port-cartier
# Processing Record 40 of Set 7 | aksay
# Processing Record 41 of Set 7 | ilebo
# Processing Record 42 of Set 7 | faya
# Processing Record 43 of Set 7 | portland
# Processing Record 44 of Set 7 | kirakira
# Processing Record 45 of Set 7 | roxana
# Processing Record 46 of Set 7 | teguldet
# Processing Record 47 of Set 7 | olafsvik
# Processing Record 48 of Set 7 | juneau
# Processing Record 49 of Set 7 | port keats
# Processing Record 50 of Set 7 | andros town
# Processing Record 1 of Set 8 | turukhansk
# Processing Record 2 of Set 8 | elesbao veloso
# Processing Record 3 of Set 8 | magadan
# Processing Record 4 of Set 8 | talara
# Processing Record 5 of Set 8 | papparapatti
# City not found. Skipping...
# Processing Record 6 of Set 8 | mangai
# Processing Record 7 of Set 8 | bhadrachalam
# Processing Record 8 of Set 8 | lasa
# Processing Record 9 of Set 8 | uzventis
# Processing Record 10 of Set 8 | baijiantan
# Processing Record 11 of Set 8 | tuatapere
# Processing Record 12 of Set 8 | praia
# Processing Record 13 of Set 8 | llangefni
# Processing Record 14 of Set 8 | tura
# Processing Record 15 of Set 8 | redmond
# Processing Record 16 of Set 8 | saldanha
# Processing Record 17 of Set 8 | miraflores
# Processing Record 18 of Set 8 | ponta delgada
# Processing Record 19 of Set 8 | muravlenko
# Processing Record 20 of Set 8 | victoria
# Processing Record 21 of Set 8 | itoman
# Processing Record 22 of Set 8 | boshnyakovo
# Processing Record 23 of Set 8 | winslow
# Processing Record 24 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 25 of Set 8 | monroe
# Processing Record 26 of Set 8 | aykhal
# Processing Record 27 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 8 | zhanaozen
# Processing Record 29 of Set 8 | carnarvon
# Processing Record 30 of Set 8 | ulagan
# Processing Record 31 of Set 8 | rawson
# Processing Record 32 of Set 8 | agadir
# Processing Record 33 of Set 8 | boende
# Processing Record 34 of Set 8 | yumen
# Processing Record 35 of Set 8 | petrolandia
# City not found. Skipping...
# Processing Record 36 of Set 8 | fukue
# Processing Record 37 of Set 8 | snyder
# Processing Record 38 of Set 8 | lagoa
# Processing Record 39 of Set 8 | ivanava
# Processing Record 40 of Set 8 | nichinan
# Processing Record 41 of Set 8 | seoul
# Processing Record 42 of Set 8 | antofagasta
# Processing Record 43 of Set 8 | gwadar
# Processing Record 44 of Set 8 | waw
# Processing Record 45 of Set 8 | menongue
# Processing Record 46 of Set 8 | springbok
# Processing Record 47 of Set 8 | vila
# Processing Record 48 of Set 8 | bereda
# Processing Record 49 of Set 8 | bondo
# Processing Record 50 of Set 8 | mandera
# Processing Record 1 of Set 9 | bur gabo
# City not found. Skipping...
# Processing Record 2 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 3 of Set 9 | maniitsoq
# Processing Record 4 of Set 9 | sibolga
# Processing Record 5 of Set 9 | bonyhad
# Processing Record 6 of Set 9 | hamilton
# Processing Record 7 of Set 9 | phangnga
# Processing Record 8 of Set 9 | tikapur
# Processing Record 9 of Set 9 | staryy nadym
# Processing Record 10 of Set 9 | teknaf
# Processing Record 11 of Set 9 | daru
# Processing Record 12 of Set 9 | walvis bay
# Processing Record 13 of Set 9 | coquimbo
# Processing Record 14 of Set 9 | pacifica
# Processing Record 15 of Set 9 | hunza
# City not found. Skipping...
# Processing Record 16 of Set 9 | port hardy
# Processing Record 17 of Set 9 | kandi
# Processing Record 18 of Set 9 | odweyne
# Processing Record 19 of Set 9 | hagere hiywet
# Processing Record 20 of Set 9 | pryvillya
# Processing Record 21 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 22 of Set 9 | slupca
# Processing Record 23 of Set 9 | saint-joseph
# Processing Record 24 of Set 9 | muriti
# Processing Record 25 of Set 9 | huazolotitlan
# City not found. Skipping...
# Processing Record 26 of Set 9 | bon accord
# Processing Record 27 of Set 9 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 9 | chiang khong
# Processing Record 29 of Set 9 | catia la mar
# Processing Record 30 of Set 9 | millau
# Processing Record 31 of Set 9 | north bend
# Processing Record 32 of Set 9 | beyneu
# Processing Record 33 of Set 9 | galiwinku
# City not found. Skipping...
# Processing Record 34 of Set 9 | plymouth
# Processing Record 35 of Set 9 | kayasula
# Processing Record 36 of Set 9 | little current
# Processing Record 37 of Set 9 | bandarbeyla
# Processing Record 38 of Set 9 | lakselv
# Processing Record 39 of Set 9 | obluche
# City not found. Skipping...
# Processing Record 40 of Set 9 | hami
# Processing Record 41 of Set 9 | bambous virieux
# Processing Record 42 of Set 9 | khandbari
# Processing Record 43 of Set 9 | quatre cocos
# Processing Record 44 of Set 9 | raudeberg
# Processing Record 45 of Set 9 | raton
# Processing Record 46 of Set 9 | iqaluit
# Processing Record 47 of Set 9 | guerrero negro
# Processing Record 48 of Set 9 | manama
# Processing Record 49 of Set 9 | san jose
# Processing Record 50 of Set 9 | cabedelo
# Processing Record 1 of Set 10 | faro
# Processing Record 2 of Set 10 | leningradskiy
# Processing Record 3 of Set 10 | grand gaube
# Processing Record 4 of Set 10 | colwyn bay
# Processing Record 5 of Set 10 | derzhavinsk
# Processing Record 6 of Set 10 | acapulco
# Processing Record 7 of Set 10 | angoche
# Processing Record 8 of Set 10 | kindu
# Processing Record 9 of Set 10 | dharmanagar
# Processing Record 10 of Set 10 | pombas
# Processing Record 11 of Set 10 | prachuap khiri khan
# Processing Record 12 of Set 10 | valparaiso
# Processing Record 13 of Set 10 | viedma
# Processing Record 14 of Set 10 | batagay
# Processing Record 15 of Set 10 | porto-vecchio
# Processing Record 16 of Set 10 | panuco
# Processing Record 17 of Set 10 | mikun
# Processing Record 18 of Set 10 | jamundi
# Processing Record 19 of Set 10 | pulsano
# Processing Record 20 of Set 10 | praia da vitoria
# Processing Record 21 of Set 10 | druzhnaya gorka
# Processing Record 22 of Set 10 | pangai
# Processing Record 23 of Set 10 | flin flon
# Processing Record 24 of Set 10 | yulara
# Processing Record 25 of Set 10 | slave lake
# Processing Record 26 of Set 10 | mareeba
# Processing Record 27 of Set 10 | ribas do rio pardo
# Processing Record 28 of Set 10 | shalakusha
# Processing Record 29 of Set 10 | katherine
# Processing Record 30 of Set 10 | butterworth
# Processing Record 31 of Set 10 | san carlos de bariloche
# Processing Record 32 of Set 10 | taltal
# Processing Record 33 of Set 10 | kanniyakumari
# Processing Record 34 of Set 10 | broken hill
# Processing Record 35 of Set 10 | newberry
# Processing Record 36 of Set 10 | bonavista
# Processing Record 37 of Set 10 | havre-saint-pierre
# Processing Record 38 of Set 10 | ginir
# Processing Record 39 of Set 10 | cozumel
# Processing Record 40 of Set 10 | panacan
# Processing Record 41 of Set 10 | broome
# Processing Record 42 of Set 10 | igboho
# Processing Record 43 of Set 10 | cradock
# Processing Record 44 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 45 of Set 10 | shizukuishi
# Processing Record 46 of Set 10 | arys
# Processing Record 47 of Set 10 | meadow lake
# Processing Record 48 of Set 10 | sept-iles
# Processing Record 49 of Set 10 | kargil
# Processing Record 50 of Set 10 | skaerbaek
# Processing Record 1 of Set 11 | sao joao da barra
# Processing Record 2 of Set 11 | prince rupert
# Processing Record 3 of Set 11 | nelson bay
# Processing Record 4 of Set 11 | mahanje
# Processing Record 5 of Set 11 | havoysund
# Processing Record 6 of Set 11 | hargeysa
# Processing Record 7 of Set 11 | jian
# Processing Record 8 of Set 11 | beregovoy
# Processing Record 9 of Set 11 | ballina
# Processing Record 10 of Set 11 | rehoboth
# Processing Record 11 of Set 11 | payson
# Processing Record 12 of Set 11 | shenzhen
# Processing Record 13 of Set 11 | namibe
# Processing Record 14 of Set 11 | ciudad bolivar
# Processing Record 15 of Set 11 | shirpur
# Processing Record 16 of Set 11 | marrakesh
# Processing Record 17 of Set 11 | fairbanks
# Processing Record 18 of Set 11 | kunming
# Processing Record 19 of Set 11 | qasigiannguit
# Processing Record 20 of Set 11 | kutum
# Processing Record 21 of Set 11 | tonstad
# Processing Record 22 of Set 11 | abha
# Processing Record 23 of Set 11 | san patricio
# Processing Record 24 of Set 11 | scottsburgh
# City not found. Skipping...
# Processing Record 25 of Set 11 | maymyo
# Processing Record 26 of Set 11 | grindavik
# Processing Record 27 of Set 11 | ilulissat
# Processing Record 28 of Set 11 | chagda
# City not found. Skipping...
# Processing Record 29 of Set 11 | ostrovnoy
# Processing Record 30 of Set 11 | gogrial
# Processing Record 31 of Set 11 | husavik
# Processing Record 32 of Set 11 | firozabad
# Processing Record 33 of Set 11 | tecolutla
# Processing Record 34 of Set 11 | brufut
# Processing Record 35 of Set 11 | dunkirk
# Processing Record 36 of Set 11 | bose
# Processing Record 37 of Set 11 | ketchikan
# Processing Record 38 of Set 11 | vestmannaeyjar
# Processing Record 39 of Set 11 | goderich
# Processing Record 40 of Set 11 | zhaotong
# Processing Record 41 of Set 11 | zaozhuang
# Processing Record 42 of Set 11 | otane
# Processing Record 43 of Set 11 | newport
# Processing Record 44 of Set 11 | tommot
# Processing Record 45 of Set 11 | hervey bay
# Processing Record 46 of Set 11 | kerteh
# City not found. Skipping...
# Processing Record 47 of Set 11 | magalia
# Processing Record 48 of Set 11 | lingsugur
# Processing Record 49 of Set 11 | ixtapa
# Processing Record 50 of Set 11 | ocos
# Processing Record 1 of Set 12 | eenhana
# Processing Record 2 of Set 12 | sitka
# Processing Record 3 of Set 12 | luangwa
# Processing Record 4 of Set 12 | gumdag
# Processing Record 5 of Set 12 | nara
# Processing Record 6 of Set 12 | tobol
# Processing Record 7 of Set 12 | oranjemund
# Processing Record 8 of Set 12 | bilma
# Processing Record 9 of Set 12 | banda aceh
# Processing Record 10 of Set 12 | libenge
# Processing Record 11 of Set 12 | gravdal
# Processing Record 12 of Set 12 | okitipupa
# Processing Record 13 of Set 12 | tateyama
# Processing Record 14 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 15 of Set 12 | dabakala
# Processing Record 16 of Set 12 | evensk
# Processing Record 17 of Set 12 | sao felix do xingu
# Processing Record 18 of Set 12 | strezhevoy
# Processing Record 19 of Set 12 | shubarshi
# Processing Record 20 of Set 12 | feijo
# Processing Record 21 of Set 12 | mayo
# Processing Record 22 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 23 of Set 12 | port-gentil
# Processing Record 24 of Set 12 | teguise
# Processing Record 25 of Set 12 | yangjiang
# Processing Record 26 of Set 12 | alofi
# Processing Record 27 of Set 12 | darlowo
# Processing Record 28 of Set 12 | touros
# Processing Record 29 of Set 12 | isilkul
# Processing Record 30 of Set 12 | northam
# Processing Record 31 of Set 12 | lensk
# Processing Record 32 of Set 12 | luau
# Processing Record 33 of Set 12 | mago
# Processing Record 34 of Set 12 | palapye
# Processing Record 35 of Set 12 | chambishi
# Processing Record 36 of Set 12 | sistranda
# Processing Record 37 of Set 12 | westport
# Processing Record 38 of Set 12 | srednekolymsk
# Processing Record 39 of Set 12 | show low
# Processing Record 40 of Set 12 | dekar
# Processing Record 41 of Set 12 | ekimchan
# Processing Record 42 of Set 12 | rolim de moura
# City not found. Skipping...
# Processing Record 43 of Set 12 | pangnirtung
# Processing Record 44 of Set 12 | chicama
# Processing Record 45 of Set 12 | valdivia
# Processing Record 46 of Set 12 | la palma
# Processing Record 47 of Set 12 | birao
# Processing Record 48 of Set 12 | san miguel
# Processing Record 49 of Set 12 | nalut
# Processing Record 50 of Set 12 | padang
# Processing Record 1 of Set 13 | yongchang
# Processing Record 2 of Set 13 | kabanjahe
# Processing Record 3 of Set 13 | collierville
# Processing Record 4 of Set 13 | los llanos de aridane
# Processing Record 5 of Set 13 | dunedin
# Processing Record 6 of Set 13 | cairns
# Processing Record 7 of Set 13 | udachnyy
# Processing Record 8 of Set 13 | green valley
# Processing Record 9 of Set 13 | ambilobe
# Processing Record 10 of Set 13 | shenjiamen
# Processing Record 11 of Set 13 | shar
# Processing Record 12 of Set 13 | mitsamiouli
# Processing Record 13 of Set 13 | pataias
# Processing Record 14 of Set 13 | porto santo
# Processing Record 15 of Set 13 | stokmarknes
# Processing Record 16 of Set 13 | moroto
# Processing Record 17 of Set 13 | adavere
# Processing Record 18 of Set 13 | asau
# Processing Record 19 of Set 13 | calbuco
# Processing Record 20 of Set 13 | simao
# Processing Record 21 of Set 13 | novokizhinginsk
# Processing Record 22 of Set 13 | bukene
# Processing Record 23 of Set 13 | sulangan
# Processing Record 24 of Set 13 | satipo
# Processing Record 25 of Set 13 | kusk
# City not found. Skipping...
# Processing Record 26 of Set 13 | salaga
# Processing Record 27 of Set 13 | marawi
# Processing Record 28 of Set 13 | borazjan
# Processing Record 29 of Set 13 | tiznit
# Processing Record 30 of Set 13 | marsh harbour
# Processing Record 31 of Set 13 | abu samrah
# Processing Record 32 of Set 13 | nago
# Processing Record 33 of Set 13 | moose factory
# Processing Record 34 of Set 13 | jutai
# Processing Record 35 of Set 13 | darhan
# Processing Record 36 of Set 13 | birjand
# Processing Record 37 of Set 13 | mglin
# Processing Record 38 of Set 13 | iskateley
# Processing Record 39 of Set 13 | gravelbourg
# Processing Record 40 of Set 13 | neuquen
# Processing Record 41 of Set 13 | sangar
# Processing Record 42 of Set 13 | kolyvan
# Processing Record 43 of Set 13 | gejiu
# Processing Record 44 of Set 13 | cururupu
# Processing Record 45 of Set 13 | binga
# Processing Record 46 of Set 13 | piacabucu
# Processing Record 47 of Set 13 | belmonte
# Processing Record 48 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 49 of Set 13 | lira
# Processing Record 50 of Set 13 | kuching
# Processing Record 1 of Set 14 | egvekinot
# Processing Record 2 of Set 14 | aybak
# City not found. Skipping...
# Processing Record 3 of Set 14 | korla
# Processing Record 4 of Set 14 | borogontsy
# Processing Record 5 of Set 14 | vuktyl
# Processing Record 6 of Set 14 | chilac
# City not found. Skipping...
# Processing Record 7 of Set 14 | cabras
# Processing Record 8 of Set 14 | longhua
# Processing Record 9 of Set 14 | sabana grande de boya
# Processing Record 10 of Set 14 | havelock
# Processing Record 11 of Set 14 | tucumcari
# Processing Record 12 of Set 14 | kahului
# Processing Record 13 of Set 14 | hefei
# Processing Record 14 of Set 14 | yarada
# Processing Record 15 of Set 14 | fort-shevchenko
# Processing Record 16 of Set 14 | berbera
# Processing Record 17 of Set 14 | kogon
# Processing Record 18 of Set 14 | paamiut
# Processing Record 19 of Set 14 | bongandanga
# Processing Record 20 of Set 14 | nayoro
# Processing Record 21 of Set 14 | lethbridge
# Processing Record 22 of Set 14 | burnie
# Processing Record 23 of Set 14 | port shepstone
# Processing Record 24 of Set 14 | manta
# Processing Record 25 of Set 14 | zhigansk
# Processing Record 26 of Set 14 | kaseda
# Processing Record 27 of Set 14 | mehran
# Processing Record 28 of Set 14 | valley station
# Processing Record 29 of Set 14 | heinola
# Processing Record 30 of Set 14 | udgir
# Processing Record 31 of Set 14 | namtsy
# Processing Record 32 of Set 14 | pundaguitan
# Processing Record 33 of Set 14 | sechura
# Processing Record 34 of Set 14 | xai-xai
# Processing Record 35 of Set 14 | fare
# Processing Record 36 of Set 14 | exeter
# Processing Record 37 of Set 14 | vagay
# Processing Record 38 of Set 14 | pierre
# Processing Record 39 of Set 14 | kilosa
# Processing Record 40 of Set 14 | vientiane
# Processing Record 41 of Set 14 | majene
# Processing Record 42 of Set 14 | tadine
# Processing Record 43 of Set 14 | la tuque
# Processing Record 44 of Set 14 | latung
# Processing Record 45 of Set 14 | maltahohe
# Processing Record 46 of Set 14 | moussoro
# Processing Record 47 of Set 14 | savannah bight
# Processing Record 48 of Set 14 | ahualulco
# Processing Record 49 of Set 14 | anloga
# Processing Record 50 of Set 14 | nakusp
# Processing Record 1 of Set 15 | saint-pierre
# Processing Record 2 of Set 15 | roald
# Processing Record 3 of Set 15 | comodoro rivadavia
# Processing Record 4 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 5 of Set 15 | tupelo
# Processing Record 6 of Set 15 | seymchan
# Processing Record 7 of Set 15 | martapura
# Processing Record 8 of Set 15 | moshkovo
# Processing Record 9 of Set 15 | buenos aires
# Processing Record 10 of Set 15 | listvyanka
# Processing Record 11 of Set 15 | batsfjord
# Processing Record 12 of Set 15 | puertollano
# Processing Record 13 of Set 15 | eyl
# Processing Record 14 of Set 15 | toamasina
# Processing Record 15 of Set 15 | nenjiang
# Processing Record 16 of Set 15 | mataram
# Processing Record 17 of Set 15 | umea
# Processing Record 18 of Set 15 | polasara
# Processing Record 19 of Set 15 | nishihara
# Processing Record 20 of Set 15 | hovd
# Processing Record 21 of Set 15 | gat
# Processing Record 22 of Set 15 | araouane
# Processing Record 23 of Set 15 | nabire
# Processing Record 24 of Set 15 | santa maria
# Processing Record 25 of Set 15 | tessalit
# Processing Record 26 of Set 15 | duz
# City not found. Skipping...
# Processing Record 27 of Set 15 | nioro
# Processing Record 28 of Set 15 | ler
# Processing Record 29 of Set 15 | port blair
# Processing Record 30 of Set 15 | poya
# Processing Record 31 of Set 15 | sal rei
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Rikitea      PF -23.1203 -134.9692     73.51        84         100
# 1        Hermanus      ZA -34.4187   19.2345     52.81        80          19
# 2        Thompson      CA  55.7435  -97.8558     19.56        45          40
# 3    Punta Arenas      CL -53.1500  -70.9167     44.71        70          75
# 4          Hobart      AU -42.8794  147.3294     54.27        90         100
# ..            ...     ...      ...       ...       ...       ...         ...
# 675         Nioro      GM  13.3500  -15.7500    102.11        10           1
# 676           Ler      SS   8.3018   30.1418     83.80        58         100
# 677    Port Blair      IN  11.6667   92.7500     80.64        83          20
# 678          Poya      NC -21.3500  165.1500     70.72        88         100
# 679       Sal Rei      CV  16.1833  -22.9167     79.00        61           0
#
#      Wind Speed Current Description
# 0          9.93          light rain
# 1          7.72          light rain
# 2         23.02    scattered clouds
# 3          3.44       broken clouds
# 4          8.05     overcast clouds
# ..          ...                 ...
# 675        8.86           clear sky
# 676        9.62     overcast clouds
# 677        2.30                mist
# 678        9.66     overcast clouds
# 679       17.27           clear sky
#
# [680 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
